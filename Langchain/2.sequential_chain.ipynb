# %%
import os
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
os.environ["OPENAI_API_KEY"] = "hhhhhh"

from openai import OpenAI
client = OpenAI()

# %%
prompt1 = PromptTemplate(
    template= 'Generate detail report on {topic}',
    input_variable=["topic"]

)

prompt2 = PromptTemplate(
    template="Generate a 5 pointer summary from the following text \n {text}",
    input_variable=["text"]
)

# %%
model = ChatOpenAI()
parser = StrOutputParser()

# %%
cahin= prompt1 | model | parser | prompt2 | model | parser
result = cahin.invoke({'topic':"Batmuda Triangle"})

# %%
result
# Out:
# "1. The Bermuda Triangle, also known as the Devil's Triangle, is a region in the western part of the North Atlantic Ocean where many aircraft and ships have mysteriously disappeared.\n2. The boundaries of the Bermuda Triangle are not officially recognized and vary among experts, covering an area of about 500,000 square miles.\n3. Numerous theories, such as magnetic anomalies and extraterrestrial abductions, have been proposed to explain the disappearances in the Bermuda Triangle, but none have been proven conclusively.\n4. Famous incidents associated with the Bermuda Triangle include the disappearance of Flight 19 in 1945, which remains a source of debate and speculation.\n5. Despite the sensationalism surrounding the Bermuda Triangle, many experts believe the disappearances can be attributed to navigational errors, weather patterns, and the high volume of air and sea traffic in the area."
